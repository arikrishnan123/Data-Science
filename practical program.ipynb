# %% [markdown]
# <a href="https://colab.research.google.com/github/arikrishnan123/Data-Science/blob/main/practical%20program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
import numpy as np
a=np.array([(1,2,3), (4, 5, 6)])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
np.random.seed(0) # seed for reproducibility
x1 = np.random.randint(10, size=6) # One-dimensional array
x2 = np.random.randint(10, size=(2, 4)) # Two-dimensional array
print (x1)
print(x2)
# Out:
# [5 0 3 3 7 9]
# [[3 5 2 4]
#  [7 6 8 8]]

# %%
import numpy as np
a=np.array([(1,2,3), (4, 5, 6)])
print(a.ndim)
# Out:
# 2

# %%
import numpy as np
a=np.array([(1,2,3)])
print(a.itemsize)
# Out:
# 8

# %%
import numpy as np
a=np.array([(1,2,3)])
print(a.dtype)
# Out:
# int64

# %%
import numpy as np
a = np.array([(1,2,3,4,5,6)])
print(a.size)
print(a.shape)
# Out:
# 6
# (1, 6)

# %%
import numpy as np
a = np.array([(8,9,10),(11,12,13)])
print(a)
a=a.reshape(3,2)
print(a)
# Out:
# [[ 8  9 10]
#  [11 12 13]]
# [[ 8  9]
#  [10 11]
#  [12 13]]

# %%
import numpy as np
a=np.array([1,2,3])
print(a.min())
print(a.max())
# Out:
# 1
# 3

# %%
import numpy as np
a= np.array([(1,2,3,4),(3,4,5,6)])
print(a[0,2])
# Out:
# 3

# %%
x=np.array([(1,2,3),(3,4,5)])
y=np.array([(1,2,3),(3,4,5)])
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# [[ 2  4  6]
#  [ 6  8 10]]
# [[0 0 0]
#  [0 0 0]]
# [[ 1  4  9]
#  [ 9 16 25]]
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
import numpy as np
a=np.array([(1,2,3),(3,4,5)])
print(np.sqrt(a))
# Out:
# [[1.         1.41421356 1.73205081]
#  [1.73205081 2.         2.23606798]]

# %%
x = [1, 2, 4, 10]
print("x =", x)
print("ln(x) =", np.log(x))
print("log2(x) =", np.log2(x))
print("log10(x) =", np.log10(x))
# Out:
# x = [1, 2, 4, 10]
# ln(x) = [0.         0.69314718 1.38629436 2.30258509]
# log2(x) = [0.         1.         2.         3.32192809]
# log10(x) = [0.         0.30103    0.60205999 1.        ]

# %%
import pandas as pd
import numpy as np
import statistics as st
# Load the data
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("diabetes.csv")
print(df.shape)
print(df.info())
# Out:
#      <input type="file" id="files-b6c35cca-bd9d-4c96-ae06-f7efc1f99278" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b6c35cca-bd9d-4c96-ae06-f7efc1f99278">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df['BMI'].value_counts()
# Out:
# BMI
# 33.6    1
# 26.6    1
# 23.3    1
# 28.1    1
# 43.1    1
# 25.6    1
# 31.0    1
# 35.3    1
# 30.5    1
# 0.0     1
# Name: count, dtype: int64

# %%
df.mean()
# Out:
# Pregnancies                   4.4000
# Glucose                     127.3000
# BloodPressure                59.8000
# SkinThickness                19.9000
# Insulin                      89.3000
# BMI                          27.7100
# DiabetesPedigreeFunction      0.5078
# Age                          35.9000
# Outcome                       0.6000
# dtype: float64

# %%
df.mean(axis = 1)[0:5]
# Out:
# 0    38.469667
# 1    26.550111
# 2    34.663556
# 3    35.807444
# 4    51.043111
# dtype: float64

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       78           66.0            0.0      0.0   0.0
# 1          8.0       85            NaN            NaN      NaN  23.3
# 2          NaN       89            NaN            NaN      NaN  25.6
# 3          NaN      115            NaN            NaN      NaN  26.6
# 4          NaN      116            NaN            NaN      NaN  28.1
# 5          NaN      125            NaN            NaN      NaN  30.5
# 6          NaN      137            NaN            NaN      NaN  31.0
# 7          NaN      148            NaN            NaN      NaN  33.6
# 8          NaN      183            NaN            NaN      NaN  35.3
# 9          NaN      197            NaN            NaN      NaN  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.134   21      1.0
# 1                     0.158   26      NaN
# 2                     0.167   29      NaN
# ...

# %%
df.std()
# Out:
# Pregnancies                   3.502380
# Glucose                      40.075068
# BloodPressure                25.654976
# SkinThickness                17.978073
# Insulin                     169.937276
# BMI                          11.259016
# DiabetesPedigreeFunction      0.654114
# Age                          11.873874
# Outcome                       0.516398
# dtype: float64
